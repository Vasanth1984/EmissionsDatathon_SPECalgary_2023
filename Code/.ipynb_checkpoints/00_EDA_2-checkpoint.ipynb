# %%
#! pip install Geopandas

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from pathlib import Path


import seaborn as sns
from scipy import stats

# %%
dir_name = r'C:\Users\vasan\OneDrive\EmissionsDatathon\Zeroing Methane Emissions - Dataset'
filename_suffix = 'csv'

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_csv("plume_attribution_2019-2022 Jeremy Zhao.csv", thousands=',', skiprows = skiprows)
df.head()
# Out:
#    Unnamed: 0 source_id               candidate_id  plume_lat  plume_lon  \
# 0           0     A0001  GAO20210712t153850p0000-A  40.586588 -104.82330
# 1           1     A0002  GAO20210720t152559p0000-A  40.574605 -104.68813
# 2           2     A0002  GAO20210712t153850p0000-B  40.574387 -104.68855
# 3           3     A0002  GAO20210718t152410p0000-B  40.573827 -104.68812
# 4           4     A0003  GAO20210712t153850p0000-C  40.572121 -104.68871
#
#                   date source_type                             ipcc  \
# 0  2021-07-12 00:00:00    landfill  6A Solid Waste Disposal On Land
# 1  2021-07-20 00:00:00   livestock            3A2 Manure Management
# 2  2021-07-12 00:00:00   livestock            3A2 Manure Management
# 3  2021-07-18 00:00:00   livestock            3A2 Manure Management
# 4  2021-07-12 00:00:00   livestock            3A2 Manure Management
#
#        qplume  sigma_qplume time_of_detection plume_tif rgb_tif
# 0  198.690714     56.089373               NaN       NaN     NaN
# 1  659.384534    215.976289               NaN       NaN     NaN
# 2  458.494606    167.196121               NaN       NaN     NaN
# 3  242.145473    140.004235               NaN       NaN     NaN
# 4  425.330806    171.220361               NaN       NaN     NaN

# %%
#df = df.drop_duplicates(subset='candidate_id', keep="first")

# %%
df.shape
# Out:
# (8752, 13)

# %%
#countries = gpd.read_file(
#               gpd.datasets.get_path("naturalearth_lowres"))
#countries.head()

# %%
# initialize an axis
fig, ax = plt.subplots(figsize=(24,18))
# plot map on axis
countries = gpd.read_file(  
     gpd.datasets.get_path("naturalearth_lowres"))
countries[countries["name"] == "United States of America"].plot(color="lightgrey",
                                                 ax=ax)
# plot points
df.plot(x="plume_lon", y="plume_lat", kind="scatter", 
        c="qplume", colormap="YlOrRd", 
        title="Methane Emissions", 
        ax=ax)
# add grid
ax.grid(b=True, alpha=0.5)

plt.xlim([-130, -60])
plt.ylim([20, 50])
plt.show()

# %%
fig_ = df['qplume'].hist(figsize=(15, 10), bins=50, color="red",
                         edgecolor="black", xlabelsize=8, ylabelsize=8)

# %%
fig_ = df['sigma_qplume'].hist(figsize=(15, 10), bins=50, color="green",
                         edgecolor="black", xlabelsize=8, ylabelsize=8)

# %%
sns.set(rc = {"figure.figsize" : (11, 7)})
sns.distplot(df["qplume"], color = "black");
# Out:
# C:\Users\vasan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc = {"figure.figsize" : (11, 7)})
sns.distplot(df["sigma_qplume"], color = "black");
# Out:
# C:\Users\vasan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(df.qplume.describe())

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.distplot(df.qplume.dropna() , fit=stats.norm);
plt.subplot(1,2,2)
_=stats.probplot(df.qplume.dropna(), plot=plt)
# Out:
# count     8735.000000
# mean       532.614768
# std        767.214281
# min          6.597543
# 25%        153.238860
# 50%        283.575918
# 75%        577.069109
# max      16811.280200
# Name: qplume, dtype: float64
# C:\Users\vasan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Generate values for missing permeability values as a function of porosity
a = df['sigma_qplume']
b = df['qplume']

plt.figure(figsize=(14, 8))
plt.scatter(a, b, color='blue')
#plt.scatter(a, b1, color='orange')
plt.xlabel("sigma_qplume", size=14)
plt.ylabel("qplume", size=14)
#plt.yscale('log', nonposy='clip')
#plt.ylim([0.01, 100000])
#plt.gca().invert_yaxis()



#plt.tight_layout()
plt.show()

# %%
def detect_outliers_zscore(data, threshold=3):
    z_scores = np.abs((data - np.mean(data)) / np.std(data))
    num_outliers = np.sum(z_scores > threshold)
    return num_outliers

# %%
detect_outliers_zscore(df['qplume'], threshold=3)
# Out:
# 143

# %%
print("Upper limit",df['qplume'].mean() + 3*df['qplume'].std())
print("Lower limit",df['qplume'].mean() - 3*df['qplume'].std())
# Out:
# Upper limit 2791.6822115799678
# Lower limit -1740.8966820283185

# %%
df[(df['qplume'] > -1740.8966820283185) | (df['qplume'] <2791.6822115799678)]
# Out:
#       Unnamed: 0 source_id               candidate_id  plume_lat   plume_lon  \
# 0              0     A0001  GAO20210712t153850p0000-A  40.586588 -104.823300
# 1              1     A0002  GAO20210720t152559p0000-A  40.574605 -104.688130
# 2              2     A0002  GAO20210712t153850p0000-B  40.574387 -104.688550
# 3              3     A0002  GAO20210718t152410p0000-B  40.573827 -104.688120
# 4              4     A0003  GAO20210712t153850p0000-C  40.572121 -104.688710
# ...          ...       ...                        ...        ...         ...
# 8727        8727     M0026       ang20220523t192554-C  35.321116 -119.630860
# 8728        8728     M0027       ang20220530t185353-A  35.415291 -118.907882
# 8729        8729     M0028       ang20220530t201634-A  35.432863 -119.143592
# 8730        8730     M0028       ang20220530t212255-A  35.432875 -119.143537
# 8731        8731     M0029       ang20220530t204330-A  35.295276 -118.917104
#
#                      date source_type                             ipcc  \
# 0     2021-07-12 00:00:00    landfill  6A Solid Waste Disposal On Land
# 1     2021-07-20 00:00:00   livestock            3A2 Manure Management
# 2     2021-07-12 00:00:00   livestock            3A2 Manure Management
# 3     2021-07-18 00:00:00   livestock            3A2 Manure Management
# 4     2021-07-12 00:00:00   livestock            3A2 Manure Management
# ...                   ...         ...                              ...
# 8727  2022-05-23T19:25:54         NaN                              NaN
# 8728  2022-05-30T18:53:53         NaN                              NaN
# 8729  2022-05-30T20:16:34         NaN                              NaN
# 8730  2022-05-30T21:22:55         NaN                              NaN
# 8731  2022-05-30T20:43:30         NaN                              NaN
#
#           qplume  sigma_qplume time_of_detection  \
# 0     198.690714     56.089373               NaN
# 1     659.384534    215.976289               NaN
# 2     458.494606    167.196121               NaN
# 3     242.145473    140.004235               NaN
# 4     425.330806    171.220361               NaN
# ...          ...           ...               ...
# 8727   52.254621     30.987699               NaN
# 8728   17.016561      5.035870               NaN
# 8729   58.744973     34.625981               NaN
# 8730  262.239608    116.651579               NaN
# 8731   78.313758     14.411236               NaN
#
#                                            plume_tif  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8727  images/ang20220523t192554-C_r5152_c150_ctr.tif
# 8728  images/ang20220530t185353-A_r5149_c359_ctr.tif
# 8729  images/ang20220530t201634-A_r1030_c447_ctr.tif
# 8730   images/ang20220530t212255-A_r981_c430_ctr.tif
# 8731  images/ang20220530t204330-A_r5638_c331_ctr.tif
#
#                                              rgb_tif
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8727  images/ang20220523t192554-C_r5152_c150_rgb.tif
# 8728  images/ang20220530t185353-A_r5149_c359_rgb.tif
# 8729  images/ang20220530t201634-A_r1030_c447_rgb.tif
# 8730   images/ang20220530t212255-A_r981_c430_rgb.tif
# 8731  images/ang20220530t204330-A_r5638_c331_rgb.tif
#
# [7290 rows x 13 columns]

# %%
df2 = df[(df['qplume'] < 2791.6822115799678)]
df2.shape
# Out:
# (7147, 13)

# %%
drop_outliers_zscore(df.qplume, threshold=3)
# Out:
# 0       198.690714
# 1       659.384534
# 2       458.494606
# 3       242.145473
# 4       425.330806
#            ...
# 8727     52.254621
# 8728     17.016561
# 8729     58.744973
# 8730    262.239608
# 8731     78.313758
# Name: qplume, Length: 7147, dtype: float64

# %%
df.shape
# Out:
# (7292, 13)

# %%
# Generate values for missing permeability values as a function of porosity
a = df2['sigma_qplume']
b = df2['qplume']

plt.figure(figsize=(14, 8))
plt.scatter(a, b, color='blue')
#plt.scatter(a, b1, color='orange')
plt.xlabel("sigma_qplume", size=14)
plt.ylabel("qplume", size=14)
#plt.yscale('log', nonposy='clip')
#plt.ylim([0.01, 100000])
#plt.gca().invert_yaxis()



#plt.tight_layout()
plt.show()

# %%
print(df2.qplume.describe())

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.distplot(df2.qplume.dropna() , fit=stats.norm);
plt.subplot(1,2,2)
_=stats.probplot(df2.qplume.dropna(), plot=plt)
# Out:
# count    7147.000000
# mean      450.387594
# std       474.468856
# min         6.597543
# 25%       153.312533
# 50%       281.018725
# 75%       546.462104
# max      2788.648760
# Name: qplume, dtype: float64
# C:\Users\vasan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#References
#https://towardsdatascience.com/image-data-analysis-using-python-edddfdf128f4
#https://data-flair.training/blogs/python-remove-image-background/

# %%
df.shape
# Out:
# (8752, 13)

# %%
df.head()
# Out:
#    Unnamed: 0 source_id               candidate_id  plume_lat  plume_lon  \
# 0           0     A0001  GAO20210712t153850p0000-A  40.586588 -104.82330
# 1           1     A0002  GAO20210720t152559p0000-A  40.574605 -104.68813
# 2           2     A0002  GAO20210712t153850p0000-B  40.574387 -104.68855
# 3           3     A0002  GAO20210718t152410p0000-B  40.573827 -104.68812
# 4           4     A0003  GAO20210712t153850p0000-C  40.572121 -104.68871
#
#                   date source_type                             ipcc  \
# 0  2021-07-12 00:00:00    landfill  6A Solid Waste Disposal On Land
# 1  2021-07-20 00:00:00   livestock            3A2 Manure Management
# 2  2021-07-12 00:00:00   livestock            3A2 Manure Management
# 3  2021-07-18 00:00:00   livestock            3A2 Manure Management
# 4  2021-07-12 00:00:00   livestock            3A2 Manure Management
#
#        qplume  sigma_qplume time_of_detection plume_tif rgb_tif
# 0  198.690714     56.089373               NaN       NaN     NaN
# 1  659.384534    215.976289               NaN       NaN     NaN
# 2  458.494606    167.196121               NaN       NaN     NaN
# 3  242.145473    140.004235               NaN       NaN     NaN
# 4  425.330806    171.220361               NaN       NaN     NaN

# %%
df3 = pd.read_csv("source_list_2019-2022 Jeremy Zhao.csv", thousands=',', skiprows = skiprows)
df3.head()
# Out:
#    Unnamed: 0 source_id  source_lat  source_lon  number_overflights  \
# 0           0     G0001   35.249160  -119.57875                   7
# 1           1     G0002   35.082251  -119.30443                   7
# 2           2     G0003   35.367999  -119.68495                   7
# 3           3     G0004   35.343365  -119.64244                   7
# 4           4     G0005   35.359342  -119.66100                   7
#
#    source_persistence     qsource  sigma_qsource source_type  \
# 0            0.142857   96.853478      33.082042        tank
# 1            0.142857    5.364176       1.441589  compressor
# 2            0.857143  187.200884      79.748988    pipeline
# 3            0.285714   44.889285      24.739863    pipeline
# 4            1.000000  880.375832     244.909184    pipeline
#
#   confidence_in_persistence
# 0                      high
# 1                       low
# 2                      high
# 3                      high
# 4                      high

# %%
df3.shape
# Out:
# (4199, 10)

# %%
image_train = Path('C:/Users/vasan/OneDrive/EmissionsDatathon/Dataset/Data/Train2')

# %%
filepaths = pd.Series(list(image_train.glob(r'**/*.png')), name='Filepath').astype(str)

# %%
df_filepaths = filepaths.to_frame()

# %%
df_filepaths
# Out:
#                                                Filepath
# 0     C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 1     C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 2     C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 3     C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 4     C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# ...                                                 ...
# 3054  C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 3055  C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 3056  C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 3057  C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
# 3058  C:\Users\vasan\OneDrive\EmissionsDatathon\Data...
#
# [3059 rows x 1 columns]
